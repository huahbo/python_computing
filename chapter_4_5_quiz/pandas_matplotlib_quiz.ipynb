# %% [markdown]
# # Pandas & Matplotlib 深度练习（试题）
#
# **说明**：
# - 共有 30 道题，覆盖 `简单 / 中等 / 困难` 三个等级。
# - 每题包含：题目描述、隐藏提示（点击展开）、以及供学生填写的代码单元。
# - Python 版本：3.10+
# - 你需要在每个 `# TODO` 注释处填写代码并运行。

# %% [markdown]
# ### 题 1 （容易）: 读取与基础索引
#
# 使用 pandas 从 CSV（假设已经加载为字符串或DataFrame）读取数据，并演示如何通过列标签和位置选择数据。要求：创建一个示例 DataFrame，展示 .loc 和 .iloc 的区别，并选出第2行第'B'列的值。
#
# <details><summary>提示（点击展开）</summary>
#
# 构造一个三列（A,B,C），五行的 DataFrame，用 .loc 以标签取值，.iloc 以位置取值。注意 loc 的标签必须存在。
#
# </details>

# %%
# --- 请在此处填写代码 ---
# 示例：
# import pandas as pd
# df = pd.DataFrame(...)

# TODO: 实现题目要求

pass

# %% [markdown]
# ### 题 2 （容易）: 缺失值处理
#
# 创建一个包含缺失值的 DataFrame，演示三种处理缺失值的方法：删除行、前向填充（ffill）、用列中位数替换。要求：展示处理前后统计信息。
#
# <details><summary>提示（点击展开）</summary>
#
# 使用 df.dropna(), df.fillna(method='ffill'), df.fillna(value=median_dict) 等方法。
#
# </details>

# %%
# --- 请在此处填写代码 ---
# 示例：
# import pandas as pd
# df = pd.DataFrame(...)

# TODO: 实现题目要求

pass

# %% [markdown]
# ### 题 3 （容易）: 分组聚合 (groupby)
#
# 构造一个 DataFrame 包含列 'Category'、'Value'，对 'Category' 分组并计算均值、标准差与计数；然后筛选出均值大于某阈值的组。
#
# <details><summary>提示（点击展开）</summary>
#
# 使用 df.groupby('Category').agg(['mean','std','count']) 或者自定义 agg字典。筛选可以用 reset_index() 后布尔索引。
#
# </details>

# %%
# --- 请在此处填写代码 ---
# 示例：
# import pandas as pd
# df = pd.DataFrame(...)

# TODO: 实现题目要求

pass

# %% [markdown]
# ### 题 4 （容易）: 透视表 (pivot_table) 与 多级索引
#
# 基于示例数据创建 pivot_table：index 为 'Category'，columns 为 'Type'，values 为 'Value'，aggfunc 为 sum。然后说明输出 DataFrame 的 index/columns类型。
#
# <details><summary>提示（点击展开）</summary>
#
# 使用 pd.pivot_table(df, values='Value', index='Category', columns='Type', aggfunc='sum')，检查 type(result.index) 与 isinstance(result.columns, pd.MultiIndex)。
#
# </details>

# %%
# --- 请在此处填写代码 ---
# 示例：
# import pandas as pd
# df = pd.DataFrame(...)

# TODO: 实现题目要求

pass

# %% [markdown]
# ### 题 5 （容易）: 时间序列与重采样 (resample)
#
# 创建一个按小时索引的时间序列 DataFrame，计算日（日频）总和与7天滚动平均（rolling）。要求显示结果的头部。
#
# <details><summary>提示（点击展开）</summary>
#
# 使用 pd.date_range 生成 DatetimeIndex，设置 freq='H'。DataFrame.resample('D').sum() 和 df.rolling(window=7).mean()。注意 rolling 的 window 是基于行数。
#
# </details>

# %%
# --- 请在此处填写代码 ---
# 示例：
# import pandas as pd
# df = pd.DataFrame(...)

# TODO: 实现题目要求

pass

# %% [markdown]
# ### 题 6 （容易）: Matplotlib 基础绘图
#
# 使用 matplotlib 绘制一张含两条曲线（sin 和 cos）的图表，并添加图例、网格、标题与 x/y 标签。要求：保存为 PNG 文件（'plot_q_<i>.png'）。
#
# <details><summary>提示（点击展开）</summary>
#
# 使用 plt.figure(figsize=...), plt.plot(x,y,label=...), plt.legend(), plt.grid(True), plt.savefig('plot_q.png')。
#
# </details>

# %%
# --- 请在此处填写代码 ---
# 示例：
# import pandas as pd
# df = pd.DataFrame(...)

# TODO: 实现题目要求

pass

# %% [markdown]
# ### 题 7 （容易）: 读取与基础索引
#
# 使用 pandas 从 CSV（假设已经加载为字符串或DataFrame）读取数据，并演示如何通过列标签和位置选择数据。要求：创建一个示例 DataFrame，展示 .loc 和 .iloc 的区别，并选出第2行第'B'列的值。
#
# <details><summary>提示（点击展开）</summary>
#
# 构造一个三列（A,B,C），五行的 DataFrame，用 .loc 以标签取值，.iloc 以位置取值。注意 loc 的标签必须存在。
#
# </details>

# %%
# --- 请在此处填写代码 ---
# 示例：
# import pandas as pd
# df = pd.DataFrame(...)

# TODO: 实现题目要求

pass

# %% [markdown]
# ### 题 8 （容易）: 缺失值处理
#
# 创建一个包含缺失值的 DataFrame，演示三种处理缺失值的方法：删除行、前向填充（ffill）、用列中位数替换。要求：展示处理前后统计信息。
#
# <details><summary>提示（点击展开）</summary>
#
# 使用 df.dropna(), df.fillna(method='ffill'), df.fillna(value=median_dict) 等方法。
#
# </details>

# %%
# --- 请在此处填写代码 ---
# 示例：
# import pandas as pd
# df = pd.DataFrame(...)

# TODO: 实现题目要求

pass

# %% [markdown]
# ### 题 9 （容易）: 分组聚合 (groupby)
#
# 构造一个 DataFrame 包含列 'Category'、'Value'，对 'Category' 分组并计算均值、标准差与计数；然后筛选出均值大于某阈值的组。
#
# <details><summary>提示（点击展开）</summary>
#
# 使用 df.groupby('Category').agg(['mean','std','count']) 或者自定义 agg字典。筛选可以用 reset_index() 后布尔索引。
#
# </details>

# %%
# --- 请在此处填写代码 ---
# 示例：
# import pandas as pd
# df = pd.DataFrame(...)

# TODO: 实现题目要求

pass

# %% [markdown]
# ### 题 10 （容易）: 透视表 (pivot_table) 与 多级索引
#
# 基于示例数据创建 pivot_table：index 为 'Category'，columns 为 'Type'，values 为 'Value'，aggfunc 为 sum。然后说明输出 DataFrame 的 index/columns类型。
#
# <details><summary>提示（点击展开）</summary>
#
# 使用 pd.pivot_table(df, values='Value', index='Category', columns='Type', aggfunc='sum')，检查 type(result.index) 与 isinstance(result.columns, pd.MultiIndex)。
#
# </details>

# %%
# --- 请在此处填写代码 ---
# 示例：
# import pandas as pd
# df = pd.DataFrame(...)

# TODO: 实现题目要求

pass

# %% [markdown]
# ### 题 11 （中等）: 时间序列与重采样 (resample)
#
# 创建一个按小时索引的时间序列 DataFrame，计算日（日频）总和与7天滚动平均（rolling）。要求显示结果的头部。
#
# <details><summary>提示（点击展开）</summary>
#
# 使用 pd.date_range 生成 DatetimeIndex，设置 freq='H'。DataFrame.resample('D').sum() 和 df.rolling(window=7).mean()。注意 rolling 的 window 是基于行数。
#
# </details>

# %%
# --- 请在此处填写代码 ---
# 示例：
# import pandas as pd
# df = pd.DataFrame(...)

# TODO: 实现题目要求

pass

# %% [markdown]
# ### 题 12 （中等）: Matplotlib 基础绘图
#
# 使用 matplotlib 绘制一张含两条曲线（sin 和 cos）的图表，并添加图例、网格、标题与 x/y 标签。要求：保存为 PNG 文件（'plot_q_<i>.png'）。
#
# <details><summary>提示（点击展开）</summary>
#
# 使用 plt.figure(figsize=...), plt.plot(x,y,label=...), plt.legend(), plt.grid(True), plt.savefig('plot_q.png')。
#
# </details>

# %%
# --- 请在此处填写代码 ---
# 示例：
# import pandas as pd
# df = pd.DataFrame(...)

# TODO: 实现题目要求

pass

# %% [markdown]
# ### 题 13 （中等）: 读取与基础索引
#
# 使用 pandas 从 CSV（假设已经加载为字符串或DataFrame）读取数据，并演示如何通过列标签和位置选择数据。要求：创建一个示例 DataFrame，展示 .loc 和 .iloc 的区别，并选出第2行第'B'列的值。
#
# <details><summary>提示（点击展开）</summary>
#
# 构造一个三列（A,B,C），五行的 DataFrame，用 .loc 以标签取值，.iloc 以位置取值。注意 loc 的标签必须存在。
#
# </details>

# %%
# --- 请在此处填写代码 ---
# 示例：
# import pandas as pd
# df = pd.DataFrame(...)

# TODO: 实现题目要求

pass

# %% [markdown]
# ### 题 14 （中等）: 缺失值处理
#
# 创建一个包含缺失值的 DataFrame，演示三种处理缺失值的方法：删除行、前向填充（ffill）、用列中位数替换。要求：展示处理前后统计信息。
#
# <details><summary>提示（点击展开）</summary>
#
# 使用 df.dropna(), df.fillna(method='ffill'), df.fillna(value=median_dict) 等方法。
#
# </details>

# %%
# --- 请在此处填写代码 ---
# 示例：
# import pandas as pd
# df = pd.DataFrame(...)

# TODO: 实现题目要求

pass

# %% [markdown]
# ### 题 15 （中等）: 分组聚合 (groupby)
#
# 构造一个 DataFrame 包含列 'Category'、'Value'，对 'Category' 分组并计算均值、标准差与计数；然后筛选出均值大于某阈值的组。
#
# <details><summary>提示（点击展开）</summary>
#
# 使用 df.groupby('Category').agg(['mean','std','count']) 或者自定义 agg字典。筛选可以用 reset_index() 后布尔索引。
#
# </details>

# %%
# --- 请在此处填写代码 ---
# 示例：
# import pandas as pd
# df = pd.DataFrame(...)

# TODO: 实现题目要求

pass

# %% [markdown]
# ### 题 16 （中等）: 透视表 (pivot_table) 与 多级索引
#
# 基于示例数据创建 pivot_table：index 为 'Category'，columns 为 'Type'，values 为 'Value'，aggfunc 为 sum。然后说明输出 DataFrame 的 index/columns类型。
#
# <details><summary>提示（点击展开）</summary>
#
# 使用 pd.pivot_table(df, values='Value', index='Category', columns='Type', aggfunc='sum')，检查 type(result.index) 与 isinstance(result.columns, pd.MultiIndex)。
#
# </details>

# %%
# --- 请在此处填写代码 ---
# 示例：
# import pandas as pd
# df = pd.DataFrame(...)

# TODO: 实现题目要求

pass

# %% [markdown]
# ### 题 17 （中等）: 时间序列与重采样 (resample)
#
# 创建一个按小时索引的时间序列 DataFrame，计算日（日频）总和与7天滚动平均（rolling）。要求显示结果的头部。
#
# <details><summary>提示（点击展开）</summary>
#
# 使用 pd.date_range 生成 DatetimeIndex，设置 freq='H'。DataFrame.resample('D').sum() 和 df.rolling(window=7).mean()。注意 rolling 的 window 是基于行数。
#
# </details>

# %%
# --- 请在此处填写代码 ---
# 示例：
# import pandas as pd
# df = pd.DataFrame(...)

# TODO: 实现题目要求

pass

# %% [markdown]
# ### 题 18 （中等）: Matplotlib 基础绘图
#
# 使用 matplotlib 绘制一张含两条曲线（sin 和 cos）的图表，并添加图例、网格、标题与 x/y 标签。要求：保存为 PNG 文件（'plot_q_<i>.png'）。
#
# <details><summary>提示（点击展开）</summary>
#
# 使用 plt.figure(figsize=...), plt.plot(x,y,label=...), plt.legend(), plt.grid(True), plt.savefig('plot_q.png')。
#
# </details>

# %%
# --- 请在此处填写代码 ---
# 示例：
# import pandas as pd
# df = pd.DataFrame(...)

# TODO: 实现题目要求

pass

# %% [markdown]
# ### 题 19 （中等）: 读取与基础索引
#
# 使用 pandas 从 CSV（假设已经加载为字符串或DataFrame）读取数据，并演示如何通过列标签和位置选择数据。要求：创建一个示例 DataFrame，展示 .loc 和 .iloc 的区别，并选出第2行第'B'列的值。
#
# <details><summary>提示（点击展开）</summary>
#
# 构造一个三列（A,B,C），五行的 DataFrame，用 .loc 以标签取值，.iloc 以位置取值。注意 loc 的标签必须存在。
#
# </details>

# %%
# --- 请在此处填写代码 ---
# 示例：
# import pandas as pd
# df = pd.DataFrame(...)

# TODO: 实现题目要求

pass

# %% [markdown]
# ### 题 20 （中等）: 缺失值处理
#
# 创建一个包含缺失值的 DataFrame，演示三种处理缺失值的方法：删除行、前向填充（ffill）、用列中位数替换。要求：展示处理前后统计信息。
#
# <details><summary>提示（点击展开）</summary>
#
# 使用 df.dropna(), df.fillna(method='ffill'), df.fillna(value=median_dict) 等方法。
#
# </details>

# %%
# --- 请在此处填写代码 ---
# 示例：
# import pandas as pd
# df = pd.DataFrame(...)

# TODO: 实现题目要求

pass

# %% [markdown]
# ### 题 21 （比较难）: 分组聚合 (groupby)
#
# 构造一个 DataFrame 包含列 'Category'、'Value'，对 'Category' 分组并计算均值、标准差与计数；然后筛选出均值大于某阈值的组。
#
# <details><summary>提示（点击展开）</summary>
#
# 使用 df.groupby('Category').agg(['mean','std','count']) 或者自定义 agg字典。筛选可以用 reset_index() 后布尔索引。
#
# </details>

# %%
# --- 请在此处填写代码 ---
# 示例：
# import pandas as pd
# df = pd.DataFrame(...)

# TODO: 实现题目要求

pass

# %% [markdown]
# ### 题 22 （比较难）: 透视表 (pivot_table) 与 多级索引
#
# 基于示例数据创建 pivot_table：index 为 'Category'，columns 为 'Type'，values 为 'Value'，aggfunc 为 sum。然后说明输出 DataFrame 的 index/columns类型。
#
# <details><summary>提示（点击展开）</summary>
#
# 使用 pd.pivot_table(df, values='Value', index='Category', columns='Type', aggfunc='sum')，检查 type(result.index) 与 isinstance(result.columns, pd.MultiIndex)。
#
# </details>

# %%
# --- 请在此处填写代码 ---
# 示例：
# import pandas as pd
# df = pd.DataFrame(...)

# TODO: 实现题目要求

pass

# %% [markdown]
# ### 题 23 （比较难）: 时间序列与重采样 (resample)
#
# 创建一个按小时索引的时间序列 DataFrame，计算日（日频）总和与7天滚动平均（rolling）。要求显示结果的头部。
#
# <details><summary>提示（点击展开）</summary>
#
# 使用 pd.date_range 生成 DatetimeIndex，设置 freq='H'。DataFrame.resample('D').sum() 和 df.rolling(window=7).mean()。注意 rolling 的 window 是基于行数。
#
# </details>

# %%
# --- 请在此处填写代码 ---
# 示例：
# import pandas as pd
# df = pd.DataFrame(...)

# TODO: 实现题目要求

pass

# %% [markdown]
# ### 题 24 （比较难）: Matplotlib 基础绘图
#
# 使用 matplotlib 绘制一张含两条曲线（sin 和 cos）的图表，并添加图例、网格、标题与 x/y 标签。要求：保存为 PNG 文件（'plot_q_<i>.png'）。
#
# <details><summary>提示（点击展开）</summary>
#
# 使用 plt.figure(figsize=...), plt.plot(x,y,label=...), plt.legend(), plt.grid(True), plt.savefig('plot_q.png')。
#
# </details>

# %%
# --- 请在此处填写代码 ---
# 示例：
# import pandas as pd
# df = pd.DataFrame(...)

# TODO: 实现题目要求

pass

# %% [markdown]
# ### 题 25 （比较难）: 读取与基础索引
#
# 使用 pandas 从 CSV（假设已经加载为字符串或DataFrame）读取数据，并演示如何通过列标签和位置选择数据。要求：创建一个示例 DataFrame，展示 .loc 和 .iloc 的区别，并选出第2行第'B'列的值。
#
# <details><summary>提示（点击展开）</summary>
#
# 构造一个三列（A,B,C），五行的 DataFrame，用 .loc 以标签取值，.iloc 以位置取值。注意 loc 的标签必须存在。
#
# </details>

# %%
# --- 请在此处填写代码 ---
# 示例：
# import pandas as pd
# df = pd.DataFrame(...)

# TODO: 实现题目要求

pass

# %% [markdown]
# ### 题 26 （比较难）: 缺失值处理
#
# 创建一个包含缺失值的 DataFrame，演示三种处理缺失值的方法：删除行、前向填充（ffill）、用列中位数替换。要求：展示处理前后统计信息。
#
# <details><summary>提示（点击展开）</summary>
#
# 使用 df.dropna(), df.fillna(method='ffill'), df.fillna(value=median_dict) 等方法。
#
# </details>

# %%
# --- 请在此处填写代码 ---
# 示例：
# import pandas as pd
# df = pd.DataFrame(...)

# TODO: 实现题目要求

pass

# %% [markdown]
# ### 题 27 （比较难）: 分组聚合 (groupby)
#
# 构造一个 DataFrame 包含列 'Category'、'Value'，对 'Category' 分组并计算均值、标准差与计数；然后筛选出均值大于某阈值的组。
#
# <details><summary>提示（点击展开）</summary>
#
# 使用 df.groupby('Category').agg(['mean','std','count']) 或者自定义 agg字典。筛选可以用 reset_index() 后布尔索引。
#
# </details>

# %%
# --- 请在此处填写代码 ---
# 示例：
# import pandas as pd
# df = pd.DataFrame(...)

# TODO: 实现题目要求

pass

# %% [markdown]
# ### 题 28 （比较难）: 透视表 (pivot_table) 与 多级索引
#
# 基于示例数据创建 pivot_table：index 为 'Category'，columns 为 'Type'，values 为 'Value'，aggfunc 为 sum。然后说明输出 DataFrame 的 index/columns类型。
#
# <details><summary>提示（点击展开）</summary>
#
# 使用 pd.pivot_table(df, values='Value', index='Category', columns='Type', aggfunc='sum')，检查 type(result.index) 与 isinstance(result.columns, pd.MultiIndex)。
#
# </details>

# %%
# --- 请在此处填写代码 ---
# 示例：
# import pandas as pd
# df = pd.DataFrame(...)

# TODO: 实现题目要求

pass

# %% [markdown]
# ### 题 29 （比较难）: 时间序列与重采样 (resample)
#
# 创建一个按小时索引的时间序列 DataFrame，计算日（日频）总和与7天滚动平均（rolling）。要求显示结果的头部。
#
# <details><summary>提示（点击展开）</summary>
#
# 使用 pd.date_range 生成 DatetimeIndex，设置 freq='H'。DataFrame.resample('D').sum() 和 df.rolling(window=7).mean()。注意 rolling 的 window 是基于行数。
#
# </details>

# %%
# --- 请在此处填写代码 ---
# 示例：
# import pandas as pd
# df = pd.DataFrame(...)

# TODO: 实现题目要求

pass

# %% [markdown]
# ### 题 30 （比较难）: Matplotlib 基础绘图
#
# 使用 matplotlib 绘制一张含两条曲线（sin 和 cos）的图表，并添加图例、网格、标题与 x/y 标签。要求：保存为 PNG 文件（'plot_q_<i>.png'）。
#
# <details><summary>提示（点击展开）</summary>
#
# 使用 plt.figure(figsize=...), plt.plot(x,y,label=...), plt.legend(), plt.grid(True), plt.savefig('plot_q.png')。
#
# </details>

# %%
# --- 请在此处填写代码 ---
# 示例：
# import pandas as pd
# df = pd.DataFrame(...)

# TODO: 实现题目要求

pass
