# %% [markdown]
# # SciPy 作业测验（第 3 章，16 题，自动评分）
#
# 说明：本 Notebook 采用自动评分，每题下面有一个测试单元，运行测试会将得分追加到 `_GRADES`。请按顺序运行。

# %%
_GRADES = []  # (qnum, score, max_pts, note)
import numpy as np
print('测验初始化 OK；请逐题完成后再运行测试单元。')

# %% [markdown]
# ### 题 1：一维定积分
#
# 用 `quad` 求 ∫0^1 x^2 dx，取 `[0]`。
#
# 请在下面的代码单元中实现（保留题中要求的变量名）。

# %% [markdown]
# <details><summary>提示（点击展开）</summary>
#
# 用 `quad` 求 ∫0^1 x^2 dx，取 `[0]`。
#
# </details>

# %%
# 在此处编写你的解答代码：

# YOUR ANSWER HERE

# %%
# Q1 test (1 point)
try:
    pts = 1
    import numpy as np
    assert abs(integral_val - 1/3) < 1e-8
    score = pts; note = 'OK'
except Exception as e:
    score = 0; note = str(e)
_GRADES.append((1, score, pts, note))
print(f"Q1: {score}/1  {note}")

# %% [markdown]
# ### 题 2：二重积分
#
# `dblquad` 的签名：内层上下限是函数。
#
# 请在下面的代码单元中实现（保留题中要求的变量名）。

# %% [markdown]
# <details><summary>提示（点击展开）</summary>
#
# `dblquad` 的签名：内层上下限是函数。
#
# </details>

# %%
# 在此处编写你的解答代码：

# YOUR ANSWER HERE

# %%
# Q2 test (1 point)
try:
    pts = 1
    assert abs(dbl_val - 0.125) < 1e-8
    score = pts; note = 'OK'
except Exception as e:
    score = 0; note = str(e)
_GRADES.append((2, score, pts, note))
print(f"Q2: {score}/1  {note}")

# %% [markdown]
# ### 题 3：一阶 ODE
#
# `solve_ivp(deriv, (0,5), [1], t_eval=[5])`，取 `sol.y[0,-1]`。
#
# 请在下面的代码单元中实现（保留题中要求的变量名）。

# %% [markdown]
# <details><summary>提示（点击展开）</summary>
#
# `solve_ivp(deriv, (0,5), [1], t_eval=[5])`，取 `sol.y[0,-1]`。
#
# </details>

# %%
# 在此处编写你的解答代码：

# YOUR ANSWER HERE

# %%
# Q3 test (1 point)
try:
    pts = 1
    import numpy as np
    assert abs(y_end - np.exp(-10)) < 1e-4
    score = pts; note = 'OK'
except Exception as e:
    score = 0; note = str(e)
_GRADES.append((3, score, pts, note))
print(f"Q3: {score}/1  {note}")

# %% [markdown]
# ### 题 4：一维求根
#
# `brentq(f, 1, 2)` 求 x^2-2。
#
# 请在下面的代码单元中实现（保留题中要求的变量名）。

# %% [markdown]
# <details><summary>提示（点击展开）</summary>
#
# `brentq(f, 1, 2)` 求 x^2-2。
#
# </details>

# %%
# 在此处编写你的解答代码：

# YOUR ANSWER HERE

# %%
# Q4 test (1 point)
try:
    pts = 1
    import numpy as np
    assert abs(root_val - np.sqrt(2)) < 1e-9
    score = pts; note = 'OK'
except Exception as e:
    score = 0; note = str(e)
_GRADES.append((4, score, pts, note))
print(f"Q4: {score}/1  {note}")

# %% [markdown]
# ### 题 5：一维极小值
#
# `brent(f, brack=(0,2))` 求 (x-1)^2。
#
# 请在下面的代码单元中实现（保留题中要求的变量名）。

# %% [markdown]
# <details><summary>提示（点击展开）</summary>
#
# `brent(f, brack=(0,2))` 求 (x-1)^2。
#
# </details>

# %%
# 在此处编写你的解答代码：

# YOUR ANSWER HERE

# %%
# Q5 test (1 point)
try:
    pts = 1
    assert abs(xmin - 1.0) < 1e-5
    score = pts; note = 'OK'
except Exception as e:
    score = 0; note = str(e)
_GRADES.append((5, score, pts, note))
print(f"Q5: {score}/1  {note}")

# %% [markdown]
# ### 题 6：指派问题
#
# `linear_sum_assignment` 返回行/列索引，用 `cost[ri, ci].sum()`。
#
# 请在下面的代码单元中实现（保留题中要求的变量名）。

# %% [markdown]
# <details><summary>提示（点击展开）</summary>
#
# `linear_sum_assignment` 返回行/列索引，用 `cost[ri, ci].sum()`。
#
# </details>

# %%
# 在此处编写你的解答代码：

# YOUR ANSWER HERE

# %%
# Q6 test (2 points)
try:
    pts = 2
    assert min_cost == 5
    score = pts; note = 'OK'
except Exception as e:
    score = 0; note = str(e)
_GRADES.append((6, score, pts, note))
print(f"Q6: {score}/2  {note}")

# %% [markdown]
# ### 题 7：线性规划
#
# 最小化 x1+x2，约束 x1+2x2>=4；`linprog` 用 `A_ub`<= 形式，需取负。
#
# 请在下面的代码单元中实现（保留题中要求的变量名）。

# %% [markdown]
# <details><summary>提示（点击展开）</summary>
#
# 最小化 x1+x2，约束 x1+2x2>=4；`linprog` 用 `A_ub`<= 形式，需取负。
#
# </details>

# %%
# 在此处编写你的解答代码：

# YOUR ANSWER HERE

# %%
# Q7 test (1 point)
try:
    pts = 1
    import numpy as np
    assert len(lp_x) == 2
    assert np.allclose(lp_x, [0.0, 2.0], atol=1e-6)
    score = pts; note = 'OK'
except Exception as e:
    score = 0; note = str(e)
_GRADES.append((7, score, pts, note))
print(f"Q7: {score}/1  {note}")

# %% [markdown]
# ### 题 8：Rosenbrock 优化
#
# `minimize(rosen, [-1.2, 1.0], method='BFGS')`。
#
# 请在下面的代码单元中实现（保留题中要求的变量名）。

# %% [markdown]
# <details><summary>提示（点击展开）</summary>
#
# `minimize(rosen, [-1.2, 1.0], method='BFGS')`。
#
# </details>

# %%
# 在此处编写你的解答代码：

# YOUR ANSWER HERE

# %%
# Q8 test (1 point)
try:
    pts = 1
    import numpy as np
    assert np.allclose(rosen_x, [1.0, 1.0], atol=1e-2)
    score = pts; note = 'OK'
except Exception as e:
    score = 0; note = str(e)
_GRADES.append((8, score, pts, note))
print(f"Q8: {score}/1  {note}")

# %% [markdown]
# ### 题 9：曲线拟合
#
# `curve_fit(model, xdata, ydata, p0=[1,1,1])`，真实参数 (2,3,1)。
#
# 请在下面的代码单元中实现（保留题中要求的变量名）。

# %% [markdown]
# <details><summary>提示（点击展开）</summary>
#
# `curve_fit(model, xdata, ydata, p0=[1,1,1])`，真实参数 (2,3,1)。
#
# </details>

# %%
# 在此处编写你的解答代码：

# YOUR ANSWER HERE

# %%
# Q9 test (1 point)
try:
    pts = 1
    import numpy as np
    assert len(params) == 3
    assert np.allclose(params, [2, 3, 1], atol=0.5)
    score = pts; note = 'OK'
except Exception as e:
    score = 0; note = str(e)
_GRADES.append((9, score, pts, note))
print(f"Q9: {score}/1  {note}")

# %% [markdown]
# ### 题 10：一维插值
#
# `CubicSpline([0,1,2],[0,1,0])`，在 0.5 处取值。
#
# 请在下面的代码单元中实现（保留题中要求的变量名）。

# %% [markdown]
# <details><summary>提示（点击展开）</summary>
#
# `CubicSpline([0,1,2],[0,1,0])`，在 0.5 处取值。
#
# </details>

# %%
# 在此处编写你的解答代码：

# YOUR ANSWER HERE

# %%
# Q10 test (1 point)
try:
    pts = 1
    assert abs(interp05 - 0.75) < 1e-6
    score = pts; note = 'OK'
except Exception as e:
    score = 0; note = str(e)
_GRADES.append((10, score, pts, note))
print(f"Q10: {score}/1  {note}")

# %% [markdown]
# ### 题 11：多维插值
#
# `RegularGridInterpolator((x,y), Z)`，点 (0.5,0.5)。
#
# 请在下面的代码单元中实现（保留题中要求的变量名）。

# %% [markdown]
# <details><summary>提示（点击展开）</summary>
#
# `RegularGridInterpolator((x,y), Z)`，点 (0.5,0.5)。
#
# </details>

# %%
# 在此处编写你的解答代码：

# YOUR ANSWER HERE

# %%
# Q11 test (1 point)
try:
    pts = 1
    assert abs(grid_val - 1.0) < 1e-9
    score = pts; note = 'OK'
except Exception as e:
    score = 0; note = str(e)
_GRADES.append((11, score, pts, note))
print(f"Q11: {score}/1  {note}")

# %% [markdown]
# ### 题 12：正态性检验
#
# `shapiro(rng.normal(0,1,100))` 取 p 值。
#
# 请在下面的代码单元中实现（保留题中要求的变量名）。

# %% [markdown]
# <details><summary>提示（点击展开）</summary>
#
# `shapiro(rng.normal(0,1,100))` 取 p 值。
#
# </details>

# %%
# 在此处编写你的解答代码：

# YOUR ANSWER HERE

# %%
# Q12 test (1 point)
try:
    pts = 1
    assert p_norm > 0.05
    score = pts; note = 'OK'
except Exception as e:
    score = 0; note = str(e)
_GRADES.append((12, score, pts, note))
print(f"Q12: {score}/1  {note}")

# %% [markdown]
# ### 题 13：独立样本 t 检验
#
# 两组正态，均值 0 / 0.5，用 `ttest_ind` 取 p 值。
#
# 请在下面的代码单元中实现（保留题中要求的变量名）。

# %% [markdown]
# <details><summary>提示（点击展开）</summary>
#
# 两组正态，均值 0 / 0.5，用 `ttest_ind` 取 p 值。
#
# </details>

# %%
# 在此处编写你的解答代码：

# YOUR ANSWER HERE

# %%
# Q13 test (1 point)
try:
    pts = 1
    assert p_tt < 0.05
    score = pts; note = 'OK'
except Exception as e:
    score = 0; note = str(e)
_GRADES.append((13, score, pts, note))
print(f"Q13: {score}/1  {note}")

# %% [markdown]
# ### 题 14：卡方独立性检验
#
# `chi2_contingency(np.array([[10,20],[30,40]]))` 取 p 值。
#
# 请在下面的代码单元中实现（保留题中要求的变量名）。

# %% [markdown]
# <details><summary>提示（点击展开）</summary>
#
# `chi2_contingency(np.array([[10,20],[30,40]]))` 取 p 值。
#
# </details>

# %%
# 在此处编写你的解答代码：

# YOUR ANSWER HERE

# %%
# Q14 test (1 point)
try:
    pts = 1
    assert 0 < p_chi < 1 and p_chi > 0.05
    score = pts; note = 'OK'
except Exception as e:
    score = 0; note = str(e)
_GRADES.append((14, score, pts, note))
print(f"Q14: {score}/1  {note}")

# %% [markdown]
# ### 题 15：FFT 主频
#
# `rfft` + `rfftfreq`，找 `argmax`。
#
# 请在下面的代码单元中实现（保留题中要求的变量名）。

# %% [markdown]
# <details><summary>提示（点击展开）</summary>
#
# `rfft` + `rfftfreq`，找 `argmax`。
#
# </details>

# %%
# 在此处编写你的解答代码：

# YOUR ANSWER HERE

# %%
# Q15 test (1 point)
try:
    pts = 1
    assert abs(peak_freq - 5.0) < 1e-6
    score = pts; note = 'OK'
except Exception as e:
    score = 0; note = str(e)
_GRADES.append((15, score, pts, note))
print(f"Q15: {score}/1  {note}")

# %% [markdown]
# ### 题 16：低通滤波
#
# `butter(3, 80/(0.5*fs), btype='low')` + `filtfilt`，与 50 Hz 参考求相关系数。
#
# 请在下面的代码单元中实现（保留题中要求的变量名）。

# %% [markdown]
# <details><summary>提示（点击展开）</summary>
#
# `butter(3, 80/(0.5*fs), btype='low')` + `filtfilt`，与 50 Hz 参考求相关系数。
#
# </details>

# %%
# 在此处编写你的解答代码：

# YOUR ANSWER HERE

# %%
# Q16 test (1 point)
try:
    pts = 1
    assert corr_lp > 0.9
    score = pts; note = 'OK'
except Exception as e:
    score = 0; note = str(e)
_GRADES.append((16, score, pts, note))
print(f"Q16: {score}/1  {note}")

# %%
# 汇总评分
total = sum(x[1] for x in _GRADES)
max_total = sum(x[2] for x in _GRADES)
print('\n=== 评分汇总 ===')
for q, s, m, note in _GRADES:
    print(f'Q{q}: {s}/{m}  {note}')
print(f'总分: {total}/{max_total}')
