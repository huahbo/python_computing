# %% [markdown]
# # SymPy 作业 - 测验版
#
# 说明：本 Notebook 采用自动评分，每题下面有一个测试单元，运行测试会将得分追加到 _GRADES 列表。
# 请按顺序运行单元。

# %%
# 自动评分初始化
_GRADES = []
import sympy as sp

# %% [markdown]
# ### 题 1
# 使用 SymPy 创建符号变量 x, y 并构造表达式 expr = x**2 + 2*x*y + y**2。
# 请在代码区定义 x, y 与 expr。

# %% [markdown]
# <details><summary>提示（点击展开）</summary>
#
# 提示：from sympy import symbols; x,y = symbols('x y')
#
# </details>

# %%
import sympy as sp
x, y = sp.symbols('x y')
expr = x**2 + 2*x*y + y**2

# %%
# Q1 test (2 points)
try:
    pts = 2
    assert sp.simplify(expr - (x**2 + 2*x*y + y**2)) == 0
    score = pts; note='OK'
except Exception as e:
    score = 0; note=str(e)
_GRADES.append((1, score, pts, note))
print('Q1:', score, '/', pts, note)

# %% [markdown]
# ### 题 2
# 对上一题中的 expr 对 x 求偏导，得到 df_dx。

# %% [markdown]
# <details><summary>提示（点击展开）</summary>
#
# 提示：sp.diff(expr, x)
#
# </details>

# %%
import sympy as sp
x, y = sp.symbols('x y')
expr = x**2 + 2*x*y + y**2
df_dx = sp.diff(expr, x)

# %%
# Q2 test (2 points)
try:
    pts = 2
    assert sp.simplify(df_dx - (2*x + 2*y)) == 0
    score = pts; note='OK'
except Exception as e:
    score = 0; note=str(e)
_GRADES.append((2, score, pts, note))
print('Q2:', score, '/', pts, note)

# %% [markdown]
# ### 题 3
# 用 SymPy 求极限 lim_{x->0} sin(x)/x，保存为 lim_val。

# %% [markdown]
# <details><summary>提示（点击展开）</summary>
#
# 提示：sp.limit(sp.sin(x)/x, x, 0)
#
# </details>

# %%
import sympy as sp
x = sp.symbols('x')
lim_val = sp.limit(sp.sin(x)/x, x, 0)

# %%
# Q3 test (2 points)
try:
    pts = 2
    assert lim_val == 1
    score = pts; note='OK'
except Exception as e:
    score = 0; note=str(e)
_GRADES.append((3, score, pts, note))
print('Q3:', score, '/', pts, note)

# %% [markdown]
# ### 题 4
# 用 SymPy 求不定积分 int (3*x**2) dx，保存为 F。

# %% [markdown]
# <details><summary>提示（点击展开）</summary>
#
# 提示：sp.integrate(3*x**2, x)
#
# </details>

# %%
import sympy as sp
x = sp.symbols('x')
F = sp.integrate(3*x**2, x)

# %%
# Q4 test (2 points)
try:
    pts = 2
    assert sp.simplify(F - x**3) == 0
    score = pts; note='OK'
except Exception as e:
    score = 0; note=str(e)
_GRADES.append((4, score, pts, note))
print('Q4:', score, '/', pts, note)

# %% [markdown]
# ### 题 5
# 把 expr = x**2 + 2*x + 1 用 lambdify 转成数值函数 f_num，并计算 val=f_num(1)。

# %% [markdown]
# <details><summary>提示（点击展开）</summary>
#
# 提示：sp.lambdify(x, expr, 'numpy')
#
# </details>

# %%
import sympy as sp
x = sp.symbols('x')
expr = x**2 + 2*x + 1
f_num = sp.lambdify(x, expr, 'numpy')
val = f_num(1)

# %%
# Q5 test (2 points)
try:
    pts = 2
    assert val == 4
    score = pts; note='OK'
except Exception as e:
    score = 0; note=str(e)
_GRADES.append((5, score, pts, note))
print('Q5:', score, '/', pts, note)

# %% [markdown]
# ### 题 6
# 用 solveset 求 x**2 - 5*x + 6 = 0 的解集，保存为 sols。

# %% [markdown]
# <details><summary>提示（点击展开）</summary>
#
# 提示：sp.solveset(expr, x)
#
# </details>

# %%
import sympy as sp
x = sp.symbols('x')
sols = sp.solveset(x**2 - 5*x + 6, x)

# %%
# Q6 test (2 points)
try:
    pts = 2
    assert sols == sp.FiniteSet(2, 3)
    score = pts; note='OK'
except Exception as e:
    score = 0; note=str(e)
_GRADES.append((6, score, pts, note))
print('Q6:', score, '/', pts, note)

# %% [markdown]
# ### 题 7
# 用 linsolve 解 A*v=b，其中 A=Matrix([[1,1,1],[2,-1,1],[1,2,2]])、b=Matrix([2,-1,3])，把解赋给 sol_vec。

# %% [markdown]
# <details><summary>提示（点击展开）</summary>
#
# 提示：sp.linsolve((A, b), (x, y, z))
#
# </details>

# %%
import sympy as sp
x, y, z = sp.symbols('x y z')
A = sp.Matrix([[1, 1, 1], [2, -1, 1], [1, 2, 2]])
b = sp.Matrix([2, -1, 3])
sol_vec = sp.linsolve((A, b), (x, y, z))

# %%
# Q7 test (2 points)
try:
    pts = 2
    assert (1, 2, -1) in sol_vec
    score = pts; note='OK'
except Exception as e:
    score = 0; note=str(e)
_GRADES.append((7, score, pts, note))
print('Q7:', score, '/', pts, note)

# %% [markdown]
# ### 题 8
# 用 SymPy 求矩阵 A=Matrix([[2,1],[1,2]]) 的特征值，保存到 eigs。

# %% [markdown]
# <details><summary>提示（点击展开）</summary>
#
# 提示：A.eigenvals()
#
# </details>

# %%
import sympy as sp
A = sp.Matrix([[2, 1], [1, 2]])
eigs = A.eigenvals()

# %%
# Q8 test (2 points)
try:
    pts = 2
    assert eigs[3] == 1 and eigs[1] == 1
    score = pts; note='OK'
except Exception as e:
    score = 0; note=str(e)
_GRADES.append((8, score, pts, note))
print('Q8:', score, '/', pts, note)

# %% [markdown]
# ### 题 9
# 构造 f1=x**2+y、f2=sin(x)-y**2，用 Matrix([f1,f2]).jacobian([x,y]) 得到 J。

# %% [markdown]
# <details><summary>提示（点击展开）</summary>
#
# 提示：sp.Matrix([...]).jacobian([x,y])
#
# </details>

# %%
import sympy as sp
x, y = sp.symbols('x y')
f1 = x**2 + y
f2 = sp.sin(x) - y**2
J = sp.Matrix([f1, f2]).jacobian([x, y])

# %%
# Q9 test (2 points)
try:
    pts = 2
    assert sp.simplify(J - sp.Matrix([[2*x, 1], [sp.cos(x), -2*y]])) == sp.zeros(2, 2)
    score = pts; note='OK'
except Exception as e:
    score = 0; note=str(e)
_GRADES.append((9, score, pts, note))
print('Q9:', score, '/', pts, note)

# %% [markdown]
# ### 题 10
# 用 factor 把 x**2 + 2*x + 1 分解为 (x+1)**2，保存到 fact_expr。

# %% [markdown]
# <details><summary>提示（点击展开）</summary>
#
# 提示：sp.factor(expr)
#
# </details>

# %%
import sympy as sp
x = sp.symbols('x')
fact_expr = sp.factor(x**2 + 2*x + 1)

# %%
# Q10 test (2 points)
try:
    pts = 2
    assert sp.simplify(fact_expr - (x + 1)**2) == 0
    score = pts; note='OK'
except Exception as e:
    score = 0; note=str(e)
_GRADES.append((10, score, pts, note))
print('Q10:', score, '/', pts, note)

# %% [markdown]
# ### 题 11
# 用 dsolve 求 y' + y = x 且 y(0)=1 的特解，保存到 sol_ode。

# %% [markdown]
# <details><summary>提示（点击展开）</summary>
#
# 提示：Function('y')(x)、Eq、ics
#
# </details>

# %%
import sympy as sp
x = sp.symbols('x')
y = sp.Function('y')(x)
eq = sp.Eq(y.diff(x) + y, x)
sol_ode = sp.dsolve(eq, y, ics={y.subs(x, 0): 1})

# %%
# Q11 test (2 points)
try:
    pts = 2
    assert sp.simplify(sol_ode.rhs - (x - 1 + 2*sp.exp(-x))) == 0
    score = pts; note='OK'
except Exception as e:
    score = 0; note=str(e)
_GRADES.append((11, score, pts, note))
print('Q11:', score, '/', pts, note)

# %%
# 汇总评分
total = sum(x[1] for x in _GRADES)
max_total = sum(x[2] for x in _GRADES)
print('Detailed per-question results:')
for q, s, m, note in _GRADES:
    print(f'Q{q}: {s}/{m} - {note}')
print('Total score:', total, '/', max_total)
